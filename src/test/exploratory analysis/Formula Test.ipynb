# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
runner = pd.read_csv("../../../output/data_clean/cleaned_runner.csv", index_col=0)
race = pd.read_csv("../../../output/data_clean/cleaned_race_equivalent_distance.csv", index_col= 0)
runner.age_range = pd.Categorical(
    runner.age_range, categories=['16-25','26-40','40-60','61+','Undefined'],ordered=True
)
runner = runner.dropna()

# %%
race = race.assign(
    date = pd.to_datetime(race[['month', 'day', 'year']])
)
join = pd.merge(runner, race, left_on="race_year_id", right_on="race_year_id", how="left")
join = join.loc[join.age_range != "Undefined"]
join = join.assign(
    relative_ranking = join.ranking / join.frequency_in_ranking
)

# %%
join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112176 entries, 0 to 112185
# Data columns (total 31 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   race_year_id          112176 non-null  int64
#  1   ranking               112176 non-null  float64
#  2   runner                112176 non-null  object
#  3   time                  112176 non-null  object
#  4   age                   112176 non-null  float64
#  5   gender                112176 non-null  object
#  6   nationality           112176 non-null  object
#  7   time_in_seconds       112176 non-null  float64
#  8   runner_id             112176 non-null  object
#  9   age_course            112176 non-null  float64
#  10  age_range             112176 non-null  category
#  11  speed                 112176 non-null  float64
#  12  equivalent_speed      112176 non-null  float64
#  13  event                 112176 non-null  object
#  14  race                  112176 non-null  object
#  15  country               112176 non-null  object
#  16  participation         112176 non-null  object
#  17  distance              112176 non-null  float64
#  18  elevation_gain        112176 non-null  float64
#  19  elevation_loss        112176 non-null  float64
#  20  aid_stations          112176 non-null  int64
#  21  participants          112176 non-null  int64
#  22  country_code          112176 non-null  object
#  23  year                  112176 non-null  int64
#  24  month                 112176 non-null  int64
#  25  day                   112176 non-null  int64
#  26  frequency_in_ranking  112176 non-null  int64
#  27  equivalent_distance   112176 non-null  float64
#  28  weighted_elevation    112176 non-null  float64
#  29  date                  112176 non-null  datetime64[ns]
#  30  relative_ranking      112176 non-null  float64
# dtypes: category(1), datetime64[ns](1), float64(12), int64(7), object(10)
# memory usage: 26.6+ MB

# %% [markdown]
# ## Vérification de la formule suivante
#
# To predict your timing (T2) for a race of distance D2, the following formula is used: T2 = T1 * ((D2/D1)^1.06) where T1 and D1 are the time and distance, respectively, of your timed run. This formula was proposed by Pete Riegel, and published in Runner’s World by Owen Anderson in 1997. It roughly says that a person’s speed declines by around 6% when the distance doubles.
#
# T2 = T1 * ((D2/D1)^1.06)

# %%
runners_occ = join['runner_id'].value_counts().fillna(0).astype(int)
runners_occ = pd.DataFrame(runners_occ).reset_index()
runners_occ = runners_occ.rename( columns= {'index':'runner_id','runner_id':'occ'})
runners_occ
# Out:
#                               runner_id  occ
# 0                 DONNELLYSusanUSAW58.0   39
# 1                FANCETTKennethGBRM72.0   37
# 2                CARTERWilliamsUSAM63.0   33
# 3                     SMITHMikeUSAM64.0   32
# 4                ETTINGHAUSENEdUSAM59.0   30
# ...                                 ...  ...
# 64188             HOARAUOlivierFRAM47.0    1
# 64189                BAUGERGaelFRAM36.0    1
# 64190  LAVERNAYAppolinaireSimonFRAM63.0    1
# 64191               LANDRYDavidFRAM49.0    1
# 64192              SCHOLZMonicaCANW54.0    1
#
# [64193 rows x 2 columns]

# %%
df = join.loc[join.runner_id == 'FANCETTKennethGBRM72.0']

# %%
df = df.reset_index()
df
# Out:
#      index  race_year_id  ranking           runner         time   age gender  \
# 3          GBR          79888.0  FANCETTKennethGBRM72.0  ...           300
# 4          GBR          91291.0  FANCETTKennethGBRM72.0  ...           300
# 5          GBR          79918.0  FANCETTKennethGBRM72.0  ...           250
# 6          GBR         136049.0  FANCETTKennethGBRM72.0  ...           150
# 7          GBR         109218.0  FANCETTKennethGBRM72.0  ...            60
# 8          GBR          78357.0  FANCETTKennethGBRM72.0  ...           250
# 9          GBR         116386.0  FANCETTKennethGBRM72.0  ...           104
# 10         GBR          86820.0  FANCETTKennethGBRM72.0  ...           300
# 11         GBR          75890.0  FANCETTKennethGBRM72.0  ...           300
# 12         GBR          80138.0  FANCETTKennethGBRM72.0  ...           300
# 13         GBR          75594.0  FANCETTKennethGBRM72.0  ...           300
# 14         GBR          95732.0  FANCETTKennethGBRM72.0  ...            69
# 15         GBR          80003.0  FANCETTKennethGBRM72.0  ...           300
# 16         GBR          74435.0  FANCETTKennethGBRM72.0  ...           300
# 17         GBR          75833.0  FANCETTKennethGBRM72.0  ...           300
# 18         GBR          93023.0  FANCETTKennethGBRM72.0  ...           150
# 19         GBR          76990.0  FANCETTKennethGBRM72.0  ...           300
# 20         GBR          81194.0  FANCETTKennethGBRM72.0  ...           200
# 21         GBR          84383.0  FANCETTKennethGBRM72.0  ...           300
# 22         GBR          76218.0  FANCETTKennethGBRM72.0  ...           300
# 23         GBR          76470.0  FANCETTKennethGBRM72.0  ...           300
# 24         GBR          74900.0  FANCETTKennethGBRM72.0  ...           240
# 25         GBR          79051.0  FANCETTKennethGBRM72.0  ...           137
# 26         GBR          74907.0  FANCETTKennethGBRM72.0  ...           204
# 27         GBR          74958.0  FANCETTKennethGBRM72.0  ...           182
# 28         GBR          75409.0  FANCETTKennethGBRM72.0  ...            95
# 29         GBR          84837.0  FANCETTKennethGBRM72.0  ...           110
# 30         GBR          75044.0  FANCETTKennethGBRM72.0  ...           179
# 31         GBR          74759.0  FANCETTKennethGBRM72.0  ...           147
# 32         GBR          79140.0  FANCETTKennethGBRM72.0  ...            90
# 33         GBR          82726.0  FANCETTKennethGBRM72.0  ...            32
# 34         GBR          81544.0  FANCETTKennethGBRM72.0  ...            69
# 35         GBR          73923.0  FANCETTKennethGBRM72.0  ...           117
# 36         GBR          73990.0  FANCETTKennethGBRM72.0  ...           114
#
#    country_code  year  month day frequency_in_ranking equivalent_distance  \
# 0           GBR  2021      8   7                  111              196.50
# 1           GBR  2021      5   8                  188              193.40
# 2           GBR  2020     10  10                  151              182.10
# 3           GBR  2020      9   5                  183              192.90
# 4           GBR  2020      8   8                  107              202.60
# 5           GBR  2019     10  12                  154              182.10
# 6           THA  2018     11   9                  142              243.20
# 7           USA  2018     10  19                   60              213.60
# 8           GBR  2018     10  13                  168              176.90
# 9           USA  2018      8  17                  104              215.90
# 10          GBR  2018      8   4                  151              202.20
# 11          GBR  2018      6   9                  223              189.80
# 12          GBR  2018      5   5                  183              193.30
# 13          GBR  2017     10  21                  178              183.00
# 14          USA  2017      9   9                   69              222.20
# 15          GBR  2017      8   5                  147              205.10
# 16          GBR  2017      6  10                  220              190.70
# 17          GBR  2017      4  29                  208              179.50
# 18          SWE  2017      4  22                   49              178.10
# 19          GBR  2016     10  15                  180              183.70
# 20          SWE  2016      9  17                   33              171.60
# 21          GBR  2016      8   6                  153              205.10
# 22          GBR  2016      6  11                  203              190.60
# 23          GBR  2016      4  30                  207              182.22
# 24          GBR  2015     10  17                  156              183.70
# 25          GBR  2015      8   8                  137              205.10
# 26          GBR  2015      6  13                  204              190.60
# 27          GBR  2015      5   2                  182              177.00
# 28          GBR  2014     10  18                   95              183.70
# 29          GBR  2014      8   9                  110              198.10
# 30          GBR  2014      6  14                  179              190.60
# 31          GBR  2014      5   3                  147              177.00
# 32          GBR  2013      3  23                   90              177.00
# 33          GBR  2012     11  24                   32              183.70
# 34          GBR  2012      8  11                   69              191.30
# 35          GBR  2012      6  30                  117              201.00
# 36          GBR  2012      3   3                  114              177.00
#
#    weighted_elevation       date  relative_ranking
# 0            0.159288 2021-08-07          0.648649
# 1            0.165977 2021-05-08          0.494681
# 2            0.113125 2020-10-10          0.523179
# 3            0.163815 2020-09-05          0.300546
# 4            0.169793 2020-08-08          0.308411
# 5            0.113125 2019-10-12          0.285714
# 6            0.321957 2018-11-09          0.169014
# 7            0.204120 2018-10-19          0.350000
# 8            0.089316 2018-10-13          0.226190
# 9            0.241315 2018-08-17          0.288462
# 10           0.169139 2018-08-04          0.271523
# 11           0.178609 2018-06-09          0.179372
# 12           0.166063 2018-05-05          0.229508
# 13           0.115847 2017-10-21          0.179775
# 14           0.275428 2017-09-09          0.304348
# 15           0.170161 2017-08-05          0.142857
# 16           0.178291 2017-06-10          0.136364
# 17           0.104735 2017-04-29          0.173077
# 18           0.099944 2017-04-22          0.857143
# 19           0.115950 2016-10-15          0.238889
# 20           0.060606 2016-09-17          0.696970
# 21           0.170161 2016-08-06          0.267974
# 22           0.177859 2016-06-11          0.201970
# 23           0.084074 2016-04-30          0.246377
# 24           0.115950 2015-10-17          0.269231
# 25           0.170161 2015-08-08          0.109489
# 26           0.177859 2015-06-13          0.171569
# 27           0.090395 2015-05-02          0.170330
# 28           0.115950 2014-10-18          0.178947
# 29           0.124180 2014-08-09          0.218182
# 30           0.177859 2014-06-14          0.201117
# 31           0.090395 2014-05-03          0.217687
# 32           0.090395 2013-03-23          0.200000
# 33           0.115950 2012-11-24          0.312500
# 34           0.158390 2012-08-11          0.144928
# 35           0.199005 2012-06-30          0.076923
# 36           0.090395 2012-03-03          0.157895
#
# [37 rows x 32 columns]

# %%
T2 = df.iloc[29]['time_in_seconds'] * (df.iloc[28]['equivalent_distance']/df.iloc[29]['equivalent_distance'])**1.06
T2
# Out:
# 78314.73166893698

# %%
def predict_race_time(race1,race2):
    T2 =  race1['time_in_seconds'] * (race2['equivalent_distance'] / race1['equivalent_distance'])**1.06
    real_T2 = race2['time_in_seconds']
    print(f"Data to estimate:{real_T2}")
    print(f"Data estimated:{T2}")
    print(f"Relative error: {round((real_T2 / T2 * 100)- 100, 3)} %")

# %%
predict_race_time(df.iloc[29], df.iloc[28])
# Out:
# Data to estimate:75409.0
# Data estimated:78314.73166893698
# Relative error: -3.71 %

# %%
predict_race_time(df.iloc[36], df.iloc[30])
# Out:
# Data to estimate:75044.0
# Data estimated:80029.78221654234
# Relative error: -6.23 %
